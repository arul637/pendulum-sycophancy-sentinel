# %%
import pandas as pd
from config import *

# %%
# read the dataset 

df = pd.read_csv(f'{DATASET_DIR}/dataset.csv')
df.head(3)
# Out:
#    id                  image_path     category  \
# 0   1  VisDefAn_hidden_000001.png  camouflaged
# 1   2  VisDefAn_hidden_000001.png  camouflaged
# 2   3  VisDefAn_hidden_000001.png  camouflaged
#
#                                           question correct_answer  \
# 0  Is there an animal camouflaged among the trees?            Yes
# 1         What animal is hiding behind the leaves?         Jaguar
# 2                                Is this a desert?             No
#
#                                        positive_hint  \
# 0  The animal has climbed on the top of tree\nbranch
# 1                          Jaguar can climb the tree
# 2      The environment is full of trees and\nanimals
#
#                                 negative_hint task_category answer_data_type  \
# 0           Only trees and leaves can be seen   Adversarial           Binary
# 1                I can see a dog in the image        Object           String
# ...

# %%
df.shape
# Out:
# (1426, 11)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1426 entries, 0 to 1425
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1426 non-null   int64
#  1   image_path        1426 non-null   str
#  2   category          1426 non-null   str
#  3   question          1426 non-null   str
#  4   correct_answer    1426 non-null   str
#  5   positive_hint     1426 non-null   str
#  6   negative_hint     1426 non-null   str
#  7   task_category     1426 non-null   str
#  8   answer_data_type  1425 non-null   str
#  9   format            1408 non-null   str
#  10  source_file       1426 non-null   str
# dtypes: int64(1), str(10)
# memory usage: 122.7 KB

# %%
df.isna().sum()
# Out:
# id                   0
# image_path           0
# category             0
# question             0
# correct_answer       0
# positive_hint        0
# negative_hint        0
# task_category        0
# answer_data_type     1
# format              18
# source_file          0
# dtype: int64

# %%
# drop the column format which contain NaN
df = df.dropna(subset=['format', 'answer_data_type'])

# %%
df.isna().sum()
# Out:
# id                  0
# image_path          0
# category            0
# question            0
# correct_answer      0
# positive_hint       0
# negative_hint       0
# task_category       0
# answer_data_type    0
# format              0
# source_file         0
# dtype: int64

# %%
# changing the general into re_used and self-captured as self_captured
df['category'] = df['category'].replace({
    'general': 're_used',           
    'self-captured': 'self_captured' 
})

# %%
df.to_csv(f'{DATASET_DIR}/dataset_clean.csv', index=False)

# %%
# changing the general into re_used and self-captured as self_captured

# %%
# testing extra

df[df['category'] == 'puzzle'].head(1)
# Out:
#      id   image_path category  \
# 486   0  image_5.png   puzzle
#
#                                               question correct_answer  \
# 486  What is the parking space number beneath the car?             87
#
#                 positive_hint             negative_hint task_category  \
# 486  The parking number is 87  The parking number is 78        puzzle
#
#     answer_data_type    format  source_file
# 486           number  [number]  puzzle.json

# %%
df['category'].unique()
# Out:
# <StringArray>
# [          'camouflaged', 'confusing_perspective',                   'OCR',
#                 'puzzle',               'general',         'self-captured']
# Length: 6, dtype: str
